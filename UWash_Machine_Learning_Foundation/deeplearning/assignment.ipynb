# %%
import graphlab
graphlab.canvas.set_target('ipynb')
image_train = graphlab.SFrame('image_train_data/')
image_test = graphlab.SFrame('image_test_data/')

# %%
image_train['label'].sketch_summary()
# Out:
# +------------------+-------+----------+
# |       item       | value | is exact |
# +------------------+-------+----------+
# |      Length      |  2005 |   Yes    |
# | # Missing Values |   0   |   Yes    |
# | # unique values  |   4   |    No    |
# +------------------+-------+----------+
#
# Most frequent items:
# +-------+------------+-----+-----+------+
# | value | automobile | cat | dog | bird |
# +-------+------------+-----+-----+------+
# | count |    509     | 509 | 509 | 478  |
# +-------+------------+-----+-----+------+

# %%
automobile_train = image_train[image_train['label'] == 'automobile']
cat_train = image_train[image_train['label'] == 'cat']
dog_train = image_train[image_train['label'] == 'dog']
bird_train = image_train[image_train['label'] == 'bird']

# %%
automobile_model = graphlab.nearest_neighbors.create(automobile_train,features=['deep_features'],
                                             label='id')
cat_model = graphlab.nearest_neighbors.create(cat_train,features=['deep_features'],
                                             label='id')
dog_model = graphlab.nearest_neighbors.create(dog_train,features=['deep_features'],
                                             label='id')
bird_model = graphlab.nearest_neighbors.create(bird_train,features=['deep_features'],
                                             label='id')
# Out:
# PROGRESS: Starting brute force nearest neighbors model training.
# PROGRESS: Starting brute force nearest neighbors model training.
# PROGRESS: Starting brute force nearest neighbors model training.
# PROGRESS: Starting brute force nearest neighbors model training.

# %%
def get_images_from_ids(query_result):
    return image_train.filter_by(query_result['reference_label'],'id')

# %%
cat_model.query(image_test[0:1])
image_train[image_train['id'] == 16289]['image'].show()
# Out:
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.196464    | 10.496ms     |
# PROGRESS: | Done         |         | 100         | 51.574ms     |
# PROGRESS: +--------------+---------+-------------+--------------+

# %%
dog_model.query(image_test[0:1])
image_train[image_train['id'] == 16976]['image'].show()
# Out:
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.196464    | 15.227ms     |
# PROGRESS: | Done         |         | 100         | 55.223ms     |
# PROGRESS: +--------------+---------+-------------+--------------+

# %%
cat_model.query(image_test[0:1])['distance'].mean()
# Out:
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.196464    | 9.418ms      |
# PROGRESS: | Done         |         | 100         | 51.518ms     |
# PROGRESS: +--------------+---------+-------------+--------------+
# 36.15573070978294

# %%
dog_model.query(image_test[0:1])['distance'].mean()
# Out:
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.196464    | 11.351ms     |
# PROGRESS: | Done         |         | 100         | 58.012ms     |
# PROGRESS: +--------------+---------+-------------+--------------+
# 37.77071136184157

# %%
automobile_test = image_test[image_test['label'] == 'automobile']
cat_test = image_test[image_test['label'] == 'cat']
dog_test = image_test[image_test['label'] == 'dog']
bird_test = image_test[image_test['label'] == 'bird']

# %%
dog_cat = cat_model.query(dog_test, k = 1)
# Out:
# PROGRESS: Starting blockwise querying.
# PROGRESS: max rows per data block: 7668
# PROGRESS: number of reference data blocks: 8
# PROGRESS: number of query data blocks: 1
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 1000         | 64000   | 12.5737     | 304.927ms    |
# PROGRESS: | Done         | 509000  | 100         | 335.378ms    |
# PROGRESS: +--------------+---------+-------------+--------------+
